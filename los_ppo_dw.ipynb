# %%
import numpy as np
from datetime import datetime, timezone
def satellite_coverage_check(r1, r2, Re=6371, threshold=500):
        r1, r2 = np.array(r1), np.array(r2)
        d = np.linalg.norm(r1 - r2)
        d_min = np.linalg.norm(np.cross(r1, r2)) / d
        return d_min > Re - threshold  # relxing the constraint

def is_on_earth(position, epsilon=10):
    R_E = 6371  #
    distance_from_center = np.linalg.norm(position)
    return abs(distance_from_center - R_E) <= epsilon
def julian_date(utc_time):
    """Convert UTC time to Julian Date."""
    unix_epoch = datetime(1970, 1, 1, 0, 0, 0, tzinfo=timezone.utc)
    delta_seconds = (utc_time - unix_epoch).total_seconds()
    julian_date = 2440587.5 + delta_seconds / 86400.0
    return julian_date

def gst_from_julian(julian_date):
    """Compute Greenwich Sidereal Time from Julian Date."""
    T = (julian_date - 2451545.0) / 36525.0
    # Compute GST in degrees, modulo 360 to stay within bounds
    GST = 280.46061837 + 360.98564736629 * (julian_date - 2451545.0) + 0.000387933 * T**2 - (T**3 / 38710000.0)
    GST = GST % 360.0  # Ensure GST is within [0, 360] degrees
    return np.radians(GST)



def geodetic_to_eci(lat_deg, lon_deg, altitude_km=0, utc_time=None):

      if utc_time is None:
        utc_time = datetime.utcnow().replace(tzinfo=timezone.utc)

      lat = np.radians(lat_deg)
      lon = np.radians(lon_deg)

      R_E = 6378.137

    # Compute the Julian Date from the given UTC time
      jd = julian_date(utc_time)

      gst = gst_from_julian(jd)

      lon_eci = lon + gst  # Longitude in the inertial frame (ECI)

      x = (R_E + altitude_km) * np.cos(lat) * np.cos(lon_eci)
      y = (R_E + altitude_km) * np.cos(lat) * np.sin(lon_eci)
      z = (R_E + altitude_km) * np.sin(lat)

      return x, y, z



def is_on_earth(position, epsilon=1e-3):#to check wether the current node is a sallite or a ground point while routing
    R_E = 6371
    distance_from_center = np.linalg.norm(position)
    return abs(distance_from_center - R_E) >= epsilon

# %%
import gym
import numpy as np
from collections import defaultdict
import matplotlib.pyplot as plt
from gym import spaces
from scipy.spatial import distance
import random
import datetime
from datetime import timezone
from datetime import datetime

# %%
import numpy as np
from datetime import datetime, timezone
def satellite_coverage_check(r1, r2, Re=6371, threshold=500):
        r1, r2 = np.array(r1), np.array(r2)
        d = np.linalg.norm(r1 - r2)
        d_min = np.linalg.norm(np.cross(r1, r2)) / d
        return d_min > Re - threshold  # relxing the constraint

def is_on_earth(position, epsilon=10):
    R_E = 6371  #
    distance_from_center = np.linalg.norm(position)
    return abs(distance_from_center - R_E) <= epsilon
def julian_date(utc_time):
    """Convert UTC time to Julian Date."""
    unix_epoch = datetime(1970, 1, 1, 0, 0, 0, tzinfo=timezone.utc)
    delta_seconds = (utc_time - unix_epoch).total_seconds()
    julian_date = 2440587.5 + delta_seconds / 86400.0
    return julian_date

def gst_from_julian(julian_date):
    """Compute Greenwich Sidereal Time from Julian Date."""
    T = (julian_date - 2451545.0) / 36525.0
    # Compute GST in degrees, modulo 360 to stay within bounds
    GST = 280.46061837 + 360.98564736629 * (julian_date - 2451545.0) + 0.000387933 * T**2 - (T**3 / 38710000.0)
    GST = GST % 360.0  # Ensure GST is within [0, 360] degrees
    return np.radians(GST)



def geodetic_to_eci(lat_deg, lon_deg, altitude_km=0, utc_time=None):

      if utc_time is None:
        utc_time = datetime.utcnow().replace(tzinfo=timezone.utc)

      lat = np.radians(lat_deg)
      lon = np.radians(lon_deg)

      R_E = 6378.137

    # Compute the Julian Date from the given UTC time
      jd = julian_date(utc_time)

      gst = gst_from_julian(jd)

      lon_eci = lon + gst  # Longitude in the inertial frame (ECI)

      x = (R_E + altitude_km) * np.cos(lat) * np.cos(lon_eci)
      y = (R_E + altitude_km) * np.cos(lat) * np.sin(lon_eci)
      z = (R_E + altitude_km) * np.sin(lat)

      return x, y, z



def is_on_earth(position, epsilon=1e-3):#to check wether the current node is a sallite or a ground point while routing
    R_E = 6371
    distance_from_center = np.linalg.norm(position)
    return abs(distance_from_center - R_E) >= epsilon

# %%
import heapq
import numpy as np
from math import radians, sin, cos, sqrt, atan2

def great_circle_distance(pos1, pos2, R_E=6371):

     #the greatcircle dist
    lat1 = np.arcsin(pos1[2] / np.linalg.norm(pos1))
    lon1 = np.arctan2(pos1[1], pos1[0])
    lat2 = np.arcsin(pos2[2] / np.linalg.norm(pos2))
    lon2 = np.arctan2(pos2[1], pos2[0])

    dlat = lat2 - lat1
    dlon = lon2 - lon1
    a = np.sin(dlat / 2)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon / 2)**2
    c = 2 * np.arcsin(np.sqrt(a))
    return R_E * c
def a_star_routing(source, target, satellite_positions, R_E=6371.8):

    # reverse lookup
    position_to_index = {tuple(v): k for k, v in satellite_positions.items()}

    if tuple(source) not in position_to_index or tuple(target) not in position_to_index:
        raise ValueError("src or tgt position not in satellite_positions.")

    open_set = []
    heapq.heappush(open_set, (0, source))  # (f_cost, current_node)

    g_cost = {tuple(pos): float('inf') for pos in satellite_positions.values()}
    g_cost[tuple(source)] = 0

    came_from = {}
    visited_sats = set()

    def edge_cost(current, neighbor):

        return great_circle_distance(np.array(current), np.array(neighbor))

    def heuristic_cost_estimate(current, goal, method="delay"):

        if method == "delay":
            return great_circle_distance(np.array(current), np.array(goal))

    def get_neighbors(current, satellite_positions, max_range=2000):

        neighbors = []
        current_pos = np.array(current)
        for pos in satellite_positions.values():
            if satellite_coverage_check(current, pos):
                neighbors.append(tuple(pos))
        return neighbors
    def reconstruct_path(came_from, current):

        path = [current]
        while current in came_from:
            current = came_from[current]
            path.insert(0, current)

        hop_distances = [edge_cost(path[i], path[i + 1]) for i in range(len(path) - 1)]
        total_distance = sum(hop_distances)

        print("hop dists:", hop_distances)
        return [position_to_index[tuple(p)] for p in path], total_distance

    while open_set:
        _, current = heapq.heappop(open_set)
        visited_sats.add(position_to_index[tuple(current)])

        if np.array_equal(current, target):
            path_indices, distance = reconstruct_path(came_from, tuple(current))
            if distance > R_E:
                print(" total  dist is  > re : the path involves multiple hops.")
            return distance, list(visited_sats), path_indices

        for neighbor in get_neighbors(current, satellite_positions):
            if tuple(neighbor) in visited_sats:
                continue
            tentative_g_cost = g_cost[tuple(current)] + edge_cost(current, neighbor)

            if tentative_g_cost < g_cost[tuple(neighbor)]:
                g_cost[tuple(neighbor)] = tentative_g_cost
                f_cost = tentative_g_cost + heuristic_cost_estimate(neighbor, target)
                heapq.heappush(open_set, (f_cost, neighbor))
                came_from[tuple(neighbor)] = tuple(current)

    return float('inf'), list(visited_sats), []  # no valid path

# %%
import numpy as np


Re = 6371
altitude = 550  #

berlin_lat, berlin_lon = 52.52, 13.405
cape_town_lat, cape_town_lon = -33.9249, 18.4241




def line_of_sight(point1, point2, R_E=6371.8):

    point1 = np.array(point1)
    point2 = np.array(point2)

    point1_to_point2 = point2 - point1

    distance = np.linalg.norm(point1_to_point2)

    point1_distance = np.linalg.norm(point1)
    point2_distance = np.linalg.norm(point2)

    angle = np.arccos(np.dot(point1_to_point2, point1) / (distance * point1_distance))

    if angle < np.pi / 2 and distance > np.sqrt(point1_distance**2 - R_E**2) + np.sqrt(point2_distance**2 - R_E**2):
        return True  # los
    else:
        return False  # Earth blocks the los


berlin_pos = geodetic_to_eci(berlin_lat, berlin_lon, 0)
cape_town_pos = geodetic_to_eci(cape_town_lat, cape_town_lon, 0)
"""

num_satellites = 100
satellites_in_los_berlin = []
satellites_in_los_cape_town = []
satellites_eci = dict()
print(cape_town_pos)

for i in range(num_satellites):
    sat_lat = np.random.uniform(-90, 90)
    sat_lon = np.random.uniform(-180, 180)
    satellite_pos = geodetic_to_eci(sat_lat, sat_lon, altitude)
    satellites_eci[i]=satellite_pos
    if line_of_sight(satellite_pos, berlin_pos):
        satellites_in_los_berlin.append((sat_lat, sat_lon, altitude))

    if line_of_sight(satellite_pos, cape_town_pos):
        satellites_in_los_cape_town.append((sat_lat, sat_lon, altitude))
"""


num_satellites = 50
satellites_in_los_berlin = {}
satellites_in_los_cape_town = {}
satellites_eci = {}
#adding ground pomts to the dict eci q
satellites_eci[0]=berlin_pos
satellites_eci[-1]=cape_town_pos

for i in range(1,num_satellites-1):
    sat_lat = np.random.uniform(-90, 90)
    sat_lon = np.random.uniform(-180, 180)
    satellite_pos = geodetic_to_eci(sat_lat, sat_lon, altitude)
    satellites_eci[i] = satellite_pos  # Add sat to dict

    if line_of_sight(satellite_pos, berlin_pos):
        satellites_in_los_berlin[i]=(sat_lat, sat_lon, altitude)

    if line_of_sight(satellite_pos, cape_town_pos):
        satellites_in_los_cape_town[i]=(sat_lat, sat_lon, altitude)


source = berlin_pos
target = cape_town_pos


distance, visited_sats, path = a_star_routing(source, target, satellites_eci)


print(f"Distance: {distance} km")
print(f"Visited Satellites: {visited_sats}")
print(f"Path indicies: {path}")
for idx in path:

  print(f"Path (ECI coordinates): {satellites_eci[idx]}")
# Out:
# hop dists: [5891.702675489439, 3847.4755427175123]
#  total  dist is  > re : the path involves multiple hops.
# Distance: 9739.178218206951 km
# Visited Satellites: [0, -1, 23]
# Path indicies: [0, 23, -1]
# Path (ECI coordinates): (1155.0341441677099, -3705.136399035042, 5061.47132572352)
# Path (ECI coordinates): (1601.1429482204198, -6740.4386403723765, -43.70910097444179)
# Path (ECI coordinates): (2011.080144949903, -4895.39597483857, -3559.6750541154174)
# /tmp/ipykernel_7218/3304185889.py:6: RuntimeWarning: invalid value encountered in scalar divide
#   d_min = np.linalg.norm(np.cross(r1, r2)) / d

# %%
import numpy as np

def delta_walker_constellation(P, S, altitude, inclination, R_E=6371.8):

    satellites = {}
    index = 0

    inclination_rad = np.radians(inclination)

    semi_major_axis = R_E + altitude
    delta_omega = 360 / P  #
    delta_nu = 360 / S     #

    for plane in range(P):
        omega = plane * delta_omega
        for sat in range(S):
            nu = sat * delta_nu
            x = semi_major_axis * (np.cos(np.radians(omega)) * np.cos(np.radians(nu)) -
                                   np.sin(np.radians(omega)) * np.sin(np.radians(nu)) * np.cos(inclination_rad))
            y = semi_major_axis * (np.sin(np.radians(omega)) * np.cos(np.radians(nu)) +
                                   np.cos(np.radians(omega)) * np.sin(np.radians(nu)) * np.cos(inclination_rad))
            z = semi_major_axis * (np.sin(np.radians(nu)) * np.sin(inclination_rad))
            satellites[index] = np.array([x, y, z])
            index += 1

    return satellites

P = 5  # planes
S = 6  # sats per plane
altitude = 800
inclination = 53
F = 1  # phasing


satellites_eci_DW = delta_walker_constellation(P, S, altitude, inclination)
berlin_pos = geodetic_to_eci(52.52, 13.405, 0)
cape_town_pos = geodetic_to_eci(-33.9249, 18.4241, 0)

satellites_eci_DW[-1] = cape_town_pos  # Cape Town
satellites_eci_DW[0] = berlin_pos      # Berlin




source = berlin_pos
target = cape_town_pos

distance, visited_sats, path_astar = a_star_routing(source, target, satellites_eci_DW)

print(f"Distance: {distance} km")
print(f"Visited Satellites: {visited_sats}")
print(f"Path indices: {path_astar}")
for idx in path_astar:
    print(f"Path (ECI coordinates): {satellites_eci_DW[idx]}")

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

def plot_constellation(satellites_eci, R_E=6371.8):
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')

    # Plot the Earth
    u, v = np.mgrid[0:2*np.pi:100j, 0:np.pi:50j]
    x = R_E * np.cos(u) * np.sin(v)
    y = R_E * np.sin(u) * np.sin(v)
    z = R_E * np.cos(v)
    ax.plot_surface(x, y, z, color='blue', alpha=0.1)

    # Plot the satellites
    for pos in satellites_eci.values():
        ax.scatter(pos[0], pos[1], pos[2], color='red')

    ax.set_xlabel('X (km)')
    ax.set_ylabel('Y (km)')
    ax.set_zlabel('Z (km)')
    plt.show()

plot_constellation(satellites_eci_DW)

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

def plot_constellation(satellites_eci, P, R_E=6371.8):
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')

    # Plot the Earth
    u, v = np.mgrid[0:2*np.pi:100j, 0:np.pi:50j]
    x = R_E * np.cos(u) * np.sin(v)
    y = R_E * np.sin(u) * np.sin(v)
    z = R_E * np.cos(v)
    ax.plot_surface(x, y, z, color='blue', alpha=0.1)

    # Define a color map for the planes
    colors = plt.cm.tab10(np.linspace(0, 1, P))  # 10 distinct colors

    # Plot the satellites with colors based on their plane
    for idx, pos in satellites_eci.items():
        plane = idx // (len(satellites_eci) // P)  # Determine the plane of the satellite
        ax.scatter(pos[0], pos[1], pos[2], color=colors[plane])

    ax.set_xlabel('X (km)')
    ax.set_ylabel('Y (km)')
    ax.set_zlabel('Z (km)')
    plt.legend()
    plt.show()

# Example usage
P = 6  # Number of planes
satellites_eci = delta_walker_constellation(P, 11, 550, 53)  # Generate constellation
plot_constellation(satellites_eci, P)

import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

def plot_constellation_with_route(satellites_eci, path_indices, start,end,R_E=6371):
    pos_berlin=berlin_pos
    pos_capetown=cape_town_pos
    fig = plt.figure(figsize=(10, 8))
    ax = fig.add_subplot(111, projection='3d')

    # Plot the Earth
    u, v = np.mgrid[0:2*np.pi:100j, 0:np.pi:50j]
    x = R_E * np.cos(u) * np.sin(v)
    y = R_E * np.sin(u) * np.sin(v)
    z = R_E * np.cos(v)
    ax.plot_surface(x, y, z, color='blue', alpha=0.1)

    # Plot all satellites
    for idx, pos in satellites_eci.items():
        if idx in path_indices:
            # Highlight satellites in the optimal route
            ax.scatter(pos[0], pos[1], pos[2], color='red', s=100, label='Optimal point' if idx == path_indices[0] else "")
        else:
            # Plot other satellites
            ax.scatter(pos[0], pos[1], pos[2], color='gray', s=50, alpha=0.5)

    # Plot the optimal route
    route_positions = [satellites_eci[idx] for idx in path_indices]
    route_x = [pos[0] for pos in route_positions]
    route_y = [pos[1] for pos in route_positions]
    route_z = [pos[2] for pos in route_positions]
    ax.plot(route_x, route_y, route_z, color='green', marker='o', markersize=8, label='Optimal Route')
    #------------------------berlin capetown
    ax.scatter(start[0],start[1],start[2], color='yellow',s=50 ,marker='*',  label='start')

    ax.scatter(end[0],end[1],end[2], color='black',s=50, marker='*', label='end ')

    # Add labels and legend
    ax.set_xlabel('X (km)')
    ax.set_ylabel('Y (km)')
    ax.set_zlabel('Z (km)')
    ax.set_title('Satellite Constellation with Optimal Route')
    plt.legend()
    plt.show()

start = berlin_pos
end = cape_town_pos
plot_constellation_with_route(satellites_eci_DW, path_astar,start,end)




P2 = 4  # planes
S2 = 4  # sats per plane
altitude = 900
inclination = 55
F = 1  # phasing


satellites_eci_DW2 = delta_walker_constellation(P2, S2, altitude, inclination)


satellites_eci_DW2[-1] = cape_town_pos  # Cape Town
satellites_eci_DW2[0] = berlin_pos      # Berlin


satellites_eci_DW2


source = berlin_pos
target = cape_town_pos

distance2, visited_sats2, path_astar2 = a_star_routing(source, target, satellites_eci_DW2)

print(f"Distance: {distance} km")
print(f"Visited Satellites: {visited_sats2}")
print(f"Path indices: {path_astar2}")
for idx in path_astar2:
    print(f"Path (ECI coordinates): {satellites_eci_DW2[idx]}")

plot_constellation_with_route(satellites_eci_DW2, path_astar2, start,end,R_E=6371)

Re=6371
new_york_pos = geodetic_to_eci(40.7128, -74.0060, 0)
tokyo_pos = geodetic_to_eci(35.6762, 139.6503, 0)
sydney_pos = geodetic_to_eci(-33.8688, 151.2093, 0)
moscow_pos = geodetic_to_eci(55.7558, 37.6173, 0)
wellington_pos = geodetic_to_eci(-41.2865, 174.7762, 0)  #

alert_pos = geodetic_to_eci(82.5018, -62.3481, 0)  # Alert, Nunavut
south_pole_pos = geodetic_to_eci(-90, 0, 0)




# Generate the Delta Walker constellation
satellites_eci_DW_a = delta_walker_constellation(P=2, S=2, altitude=400, inclination=53)

# Add ground stations to the dictionary
satellites_eci_DW_a[0] = cape_town_pos  #)
satellites_eci_DW_a[1] = berlin_pos
satellites_eci_DW_a[2] = new_york_pos
satellites_eci_DW_a[3] = tokyo_pos
satellites_eci_DW_a[4] = sydney_pos
satellites_eci_DW_a[5] = moscow_pos
satellites_eci_DW_a[6] = wellington_pos
satellites_eci_DW_a[7] = alert_pos
satellites_eci_DW_a[8] = south_pole_pos


start_end_pairs = [
    (new_york_pos, tokyo_pos),    #
    (sydney_pos, moscow_pos),
    (berlin_pos, new_york_pos),
    (cape_town_pos, sydney_pos),
    (berlin_pos, wellington_pos),
    (alert_pos,south_pole_pos)
]


results = []  # List to store results

for start, end in start_end_pairs:
    print(f"Routing from {start} to {end}")
    distance, visited_sats, path = a_star_routing(start, end, satellites_eci_DW_a)
    if distance == float('inf'):
      print("No los comeback later")
    else:
      print(f"Distance: {distance} km")
      print(f"Path indices: {path}")

    # Store results in a dictionary
    result = {
        "start": start,
        "end": end,
        "distance": distance,
        "visited_sats": visited_sats,
        "path": path
    }
    results.append(result)  # Add the result to the list

    # Print the results
    print(f"Distance: {distance} km")
    print(f"Visited Satellites: {visited_sats}")
    print(f"Path indices: {path}")
    for idx in path:
        print(f"Path (ECI coordinates): {satellites_eci_DW_a[idx]}")
    print("\n")

results[5]["distance"]-Re

plot_constellation_with_route(satellites_eci_DW_a, results[0]["path"], results[1]["start"],results[0]["end"],R_E=6371)


plot_constellation_with_route(satellites_eci_DW_a, results[1]["path"], results[1]["start"],results[1]["end"],R_E=6371)


plot_constellation_with_route(satellites_eci_DW_a, results[2]["path"], results[2]["start"],results[2]["end"],R_E=6371)

P3 = 2  # planes
S3 = 4  # sats per plane
altitude = 700
inclination = 45
F = 1  # phasing

berlin_pos = geodetic_to_eci(52.52, 13.405, 0)  #


plot_constellation_with_route(satellites_eci_DW_a, results[4]["path"], results[4]["start"],results[4]["end"],R_E=6371)

results[4]["distance"]



plot_constellation_with_route(satellites_eci_DW_a, results[5]["path"], results[5]["start"],results[5]["end"],R_E=6371)
# Out:
# /tmp/ipykernel_7218/3304185889.py:6: RuntimeWarning: invalid value encountered in scalar divide
#   d_min = np.linalg.norm(np.cross(r1, r2)) / d
# hop dists: [5840.307261306104, 3799.271662857043]
#  total  dist is  > re : the path involves multiple hops.
# Distance: 9639.578924163146 km
# Visited Satellites: [0, 24, -1]
# Path indices: [0, 24, -1]
# Path (ECI coordinates): (1155.0429817105364, -3705.1336440199866, 5061.47132572352)
# Path (ECI coordinates): [ 2216.20808026 -6820.78712357     0.        ]
# Path (ECI coordinates): (2011.091821515026, -4895.391177966555, -3559.6750541154174)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# hop dists: [6058.490725550899, 4433.084252179949]
#  total  dist is  > re : the path involves multiple hops.
# Distance: 9639.578924163146 km
# Visited Satellites: [0, 12, 6, -1]
# Path indices: [0, 12, -1]
# Path (ECI coordinates): (1155.0429817105364, -3705.1336440199866, 5061.47132572352)
# Path (ECI coordinates): [-1.33580799e-12 -7.27180000e+03  0.00000000e+00]
# Path (ECI coordinates): (2011.091821515026, -4895.391177966555, -3559.6750541154174)
# Routing from (-4545.5704297522625, -1646.4249487050217, 4160.253110955209) to (3076.986251234096, 4168.47908466141, 3719.753932886652)
# No los comeback later
# Distance: inf km
# Visited Satellites: [1, 2, 5, 7]
# Path indices: []
#
#
# Routing from (2227.5784037440876, 4804.593303787453, -3554.4914166646554) to (2379.8085377685256, -2686.6791885305315, 5272.466012431939)
# No los comeback later
# Distance: inf km
# Visited Satellites: [4, 6]
# Path indices: []
#
#
# Routing from (1155.0429817105364, -3705.1336440199866, 5061.47132572352) to (-4545.5704297522625, -1646.4249487050217, 4160.253110955209)
# hop dists: [4032.0390606321657, 4666.19907627895]
#  total  dist is  > re : the path involves multiple hops.
# Distance: 8698.238136911115 km
# Path indices: [1, 7, 2]
# Distance: 8698.238136911115 km
# Visited Satellites: [1, 2, 7]
# Path indices: [1, 7, 2]
# Path (ECI coordinates): (1155.0429817105364, -3705.1336440199866, 5061.47132572352)
# Path (ECI coordinates): (-709.1449775849567, -435.7317035154028, 6323.5973048642645)
# Path (ECI coordinates): (-4545.5704297522625, -1646.4249487050217, 4160.253110955209)
#
#
# Routing from (2011.091821515026, -4895.391177966555, -3559.6750541154174) to (2227.5784037440876, 4804.593303787453, -3554.4914166646554)
# No los comeback later
# Distance: inf km
# Visited Satellites: [0]
# Path indices: []
#
#
# Routing from (1155.0429817105364, -3705.1336440199866, 5061.47132572352) to (109.33448497445504, 4791.410011348697, -4208.451932042452)
# No los comeback later
# Distance: inf km
# Visited Satellites: [1, 2, 5, 7]
# Path indices: []
#
#
# Routing from (-709.1449775849567, -435.7317035154028, 6323.5973048642645) to (2.667616167663107e-14, -3.896361384432908e-13, -6378.137)
# No los comeback later
# Distance: inf km
# Visited Satellites: [1, 2, 5, 7]
# Path indices: []

# %%
import gym
import numpy as np
import heapq
import matplotlib.pyplot as plt
from datetime import datetime, timezone
from stable_baselines3 import A2C,PPO



"""
# Add ground stations to the dictionary
satellites_eci_DW_a[0] = cape_town_pos  #)
satellites_eci_DW_a[1] = berlin_pos
satellites_eci_DW_a[2] = new_york_pos
satellites_eci_DW_a[3] = tokyo_pos
satellites_eci_DW_a[4] = sydney_pos
satellites_eci_DW_a[5] = moscow_pos
satellites_eci_DW_a[6] = wellington_pos
satellites_eci_DW_a[7] = alert_pos
satellites_eci_DW_a[8] = south_pole_pos
"""

start_end_pairs = [
    (berlin_pos,cape_town_pos),
    (new_york_pos, tokyo_pos),    #2,3
    (sydney_pos, moscow_pos), #4,5
    (berlin_pos, new_york_pos),#5,6
    (cape_town_pos, sydney_pos),#7,8
    (berlin_pos, wellington_pos),#9,10
    (alert_pos,south_pole_pos) #11,12
]











class SatelliteRoutingEnv(gym.Env):
    def __init__(self):
        super(SatelliteRoutingEnv, self).__init__()
        self.R_E = 6371
        self.num_satellites = 3
        self.state_space_var = 3  # lat, long, h
        self.P = 4
        self.inclination = 20
        self.S = 5
        self.altitude = 500
        self.state = self._generate_random_state()

        self.satellites_eci = self.delta_walker_constellation(int(self.state[0]),int(self.state[1]),int(self.state[2]),int(self.state[3]))


        self.current_time = datetime.utcnow()
        self.A = self.geodetic_to_eci(52.52, 13.41)  # berl
        self.B = self.geodetic_to_eci(-33.92, 18.42)  # Cape

        self.A_ecef=self.geodetic_to_ecef(52.52, 13.41)
        self.B_ecef=self.geodetic_to_ecef(-33.92, 18.42)
        self.elevation_threshold = 5.0  # deg
        self.start_end_pairs=start_end_pairs
       ##################################################################
        self.satellites_eci[1] = self.A
        self.satellites_eci[0] = self.B



        # act space: multi-disc actions
        self.delta_height_range = [-100, 0, 100]
        self.delta_angle_range = [-5, 0, 5]

        self.observation_space = spaces.Box(
            low=np.array([2, 2, 100, 10]),
            high=np.array([10, 12, 1000, 90]),
            dtype=np.float32
        )

        """
        self.action_space = spaces.MultiDiscrete([
            3,  # delta P: [-1, 0, 1]
            3,  # delta in S: [-1, 0, 1]
            3,  #  delta h: [-50, 0, 50]
            3   # delta inc: [-5, 0, 5] deg
        ])
        """
        self.action_space = spaces.Box(
        low=np.array([-3, -3, -50, -5]),
        high=np.array([3, 3, 50, 5]),
        dtype=np.float32
                        )
    
    
    
    def _generate_random_state(self):
        return np.array([
            self.np_random.uniform(self.P-2, self.P+2), # x,
            self.np_random.uniform(self.S-4, self.S+4),
            self.np_random.uniform(self.altitude-200, self.altitude+200),
            self.np_random.uniform(self.inclination-20, self.inclination+20)
        ], dtype=np.float32)

    def reset(self):

        self.state = self._generate_random_state()

        
        # reg the constellation with the new parameters
        self.satellites_eci = self.delta_walker_constellation(
            int(self.state[0]),  # P
            int(self.state[1]),  # S
            self.state[2],       # alt
            self.state[3]        # inc
        )
        self.satellites_eci[1] = self.B
        self.satellites_eci[0] = self.A
        
        return np.array(self.state, dtype=np.float32)
    def compute_reward(self, distance, num_visited, path_length,has_los_to_1,has_los):
        #  reward function
        #coverage = self.calculate_coverage(self.state[2], int(self.state[0] * self.state[1]))
        latency = distance / 299792.458
        los_1_penalty = 1 if not has_los_to_1 else 0
        los_2_penalty = 1 if not has_los else 0

        print("los_1_penalty",los_1_penalty) if  has_los_to_1 else None

        reward =  (latency * 10) - (path_length * 5) - (los_1_penalty * 10) - (los_2_penalty * 10)

        return reward
    def compute_reward2(self, state,distance, path):
        reward = 0.0
        terminated = False
        truncated = False
 
        valid_los_links = 0
        path_exists = len(path) > 0
        loop_penalty = 0

        if path_exists:
          print("yes",len(path))
        # LoS link ratio
          total_hops = len(path)-1
          for i in range(total_hops):
            sat1 = self.satellites_eci[path[i]]
            sat2 = self.satellites_eci[path[i+1]]
            try :
                self.satellite_coverage_check(sat1, sat2)
                valid_los_links += 1
                #chk for loops
                if i > 0 and path[i] == path[i-1]:
                 loop_penalty -= 2.0
            except:
                continue

          los_ratio = valid_los_links / total_hops if total_hops > 0 else 0

          distance_km = distance
          latency = distance_km / 299792.458 * 1000
          latency_reward = 1 - (latency / 300)  # 300ms max expected
          los_reward = valid_los_links / total_hops

          #reward = 5.0 * los_reward + 3.0 * latency_reward
          reward= 500* valid_los_links - 50*latency
          """
          reward += (
            5.0 * los_ratio +                  # max LoS link
            2.0 * (1 / (hop_count + 1e-6)) +   # min hops
            1.5 * (1 / (latency + 1e-6)) +     # min latency
            0.5 * (1 / (distance_km + 1e-6))   # min  dis
          )
          """


        else:
         print("No path ")
         #  penalty for no path
         reward -= 1000000000000.0
         return reward ,True ,False
        return reward, terminated, truncated
    
    def compute_reward23(self, state, distance, path):
      reward = 0.0
      terminated = False
      truncated = False      
    
      optimal_hops = 4  #path with 3 hops
      max_los_ratio = 1.0
      min_distance = 5_000.0   # min path lenth 

      distance_km = distance
      latency = distance_km / 299792.458 * 1000
      latency_reward = 1 - (latency / 300)  # 300ms max expected      
    
      has_win = (
        len(path) == optimal_hops and
        self.calculate_los_ratio(path) == max_los_ratio and
        distance <= min_distance
      )
    
      if has_win:
        terminated =True 
        truncated=False 
        return 100000.0 ,True,False # mx reward
    
      standard_reward = (
        500 * self.calculate_los_ratio(path) -
        0.05 * distance -
        50 * len(path)  # penalty per hop
        -50*latency
       )
      return standard_reward,True, truncated
    def compute_reward24(self, state, distance, path):
      reward = 0.0
      terminated = False
      truncated = False

      optimal_hops = 4          
      max_los_ratio = 1.0
      min_distance = 5000.0     #  min total path  

      distance_km = max(distance, 1e-6)   
      latency = distance_km / 299792.458 * 1000  

      safe_hops = max(len(path) - 1, 1)
      los_ratio = self.calculate_los_ratio(path)  
      if not np.isfinite(los_ratio):
        los_ratio = 0.0

      has_win = (
        len(path) == optimal_hops and
        abs(los_ratio - max_los_ratio) < 1e-5 and  
        distance <= min_distance
        )

      if has_win:
        terminated = True
        truncated = False 
        return 100_000.0, terminated, truncated  # max reward

      standard_reward = (
        500.0 * los_ratio
        - 0.05 * distance_km
        - 50.0 * len(path)    # penalty per hop
        - 50.0 * latency      # penalty for  latency
      )

      # Cs
      std_reward = np.clip(standard_reward, -1e6, 1e6)
      if not np.isfinite(std_reward):
        std_reward = -1e6

      return std_reward, terminated, truncated   





    def calculate_los_ratio(self, path):
      valid_los = 0
      for i in range(len(path)-1):
        if self.satellite_coverage_check(self.satellites_eci[path[i]], self.satellites_eci[path[i+1]]):
            valid_los += 1
      return valid_los / (len(path)-1) if len(path) > 1 else 0

    def step(self, action):
        # apply  action to  DW parms

        delta_P, delta_S, delta_alt, delta_inc = action 

        #new_P = np.clip(self.state[0] + delta_P, 4, 10)
        #new_S = np.clip(self.state[1] + delta_S, 6, 12)
        #new_altitude = np.clip(self.state[2] + delta_alt * 50, 500, 1000)
        #new_inclination = np.clip(self.state[3] + delta_inc * 5, 60, 90)

        new_P=max(self.state[0] + delta_P,1)

        new_S=max(self.state[1] + delta_S,1)
        new_altitude=self.state[2] + delta_alt
        new_inclination=self.state[3] + delta_inc


        self.state = np.array([new_P, new_S, new_altitude, new_inclination], dtype=np.float32)
        #print("self.state in step",self.state)

        #  constellation with new params
        self.satellites_eci = self.delta_walker_constellation(
            int(new_P), int(new_S), new_altitude, new_inclination
        )
        #print(self.satellites_eci.keys())
        #print("self.satellites_eci in step",self.satellites_eci)
        #self.satellites_eci[0] = self.B

        #self.satellites_eci[1] = self.A
        #print("self.start_end_pairs",type(self.start_end_pairs))

        last_sat_index = max(self.satellites_eci.keys()) if self.satellites_eci else -1
        current_index = last_sat_index + 1

        for start_pos, end_pos in self.start_end_pairs:
          self.satellites_eci[current_index] = start_pos
          current_index += 1 # Increment for the next entry
    
          self.satellites_eci[current_index] = end_pos
          current_index += 1 # Increment for the next entry





        rand_point=np.random.randint(0,len(self.start_end_pairs))

        #random start and end----------------------------------
        (self.A,self.B)=self.start_end_pairs[rand_point] 




        distance, visited_sats, path = self.a_star_routing(self.A, self.B, self.satellites_eci)
        #print("distance in step",distance)

        #gs changes every step either a or b
        gs = self.B_ecef if np.random.rand() < 0.5 else self.A_ecef#


        #has_los_1=self.satellite_coverage_check_all(self.satellites_eci,self.A,path, Re=6371,threshold=500)
        #has_los_2=self.satellite_coverage_check_all(self.satellites_eci,self.B,path, Re=6371,threshold=500)

        #  reward
        #reward = self.compute_reward(distance, len(visited_sats), len(path),has_los_1,has_los_2)
        reward,terminated,truncated=self.compute_reward24(self.state,distance, path)
        print("reward in step",reward)

        terminated = False  #  termination
        return self.state, reward, terminated, {"distance": distance, "path_length": len(path)}



    def calculate_coverage(self, altitude, num_satellites):
        #  coverage  based on h and  # sats

        return 1 - np.exp(-num_satellites * altitude / (2 * (self.R_E + altitude)))

    def eci_to_lat_lon(self, eci_coords, R_E=6371):
        x, y, z = eci_coords
        r = np.sqrt(x**2 + y**2 + z**2)

        lat = np.arcsin(z / r)
        lat_deg = np.degrees(lat)

        lon = np.arctan2(y, x)
        lon_deg = np.degrees(lon)

        return lat_deg, lon_deg

    def delta_walker_constellation(self, P, S, altitude, inclination, R_E=6371):
        satellites = {}
        index = 0

        inclination_rad = np.radians(inclination)

        a = R_E + altitude

        delta_omega = 360 / P  # RAAN separation - planes
        delta_nu = 360 / S     # true anomaly separation - sats

        for plane in range(P):
            omega = plane * delta_omega  # RAAN curr plane
            for sat in range(S):
                nu = sat * delta_nu  # true anom

                x = a * (np.cos(np.radians(omega)) * np.cos(np.radians(nu)) -
                    np.sin(np.radians(omega)) * np.sin(np.radians(nu)) * np.cos(inclination_rad))
                y = a * (np.sin(np.radians(omega)) * np.cos(np.radians(nu)) +
                    np.cos(np.radians(omega)) * np.sin(np.radians(nu)) * np.cos(inclination_rad))
                z = a * (np.sin(np.radians(nu)) * np.sin(inclination_rad))
                satellites[index] = np.array([x, y, z])
                index += 1

        return satellites

    def a_star_routing(self, source, target, satellite_positions, R_E=6371.8):
        # A*
        position_to_index = {tuple(v): k for k, v in satellite_positions.items()}

        if tuple(source) not in position_to_index or tuple(target) not in position_to_index:
            raise ValueError("src or tgt position not in satellite_positions.")

        open_set = []
        heapq.heappush(open_set, (0, source))  # (f_cost, current_node)

        g_cost = {tuple(pos): float('inf') for pos in satellite_positions.values()}
        g_cost[tuple(source)] = 0

        came_from = {}
        visited_sats = set()

        def edge_cost(current, neighbor):
            return self.great_circle_distance(np.array(current), np.array(neighbor))

        def heuristic_cost_estimate(current, goal):
            return self.great_circle_distance(np.array(current), np.array(goal))

        def get_neighbors(current, satellite_positions):
            neighbors = []
            current_pos = np.array(current)
            for pos in satellite_positions.values():
                if self.satellite_coverage_check(current_pos, pos):
                    neighbors.append(tuple(pos))
            return neighbors

        def reconstruct_path(came_from, current):
            path = [current]
            while current in came_from:
                current = came_from[current]
                path.insert(0, current)
            hop_distances = [edge_cost(path[i], path[i + 1]) for i in range(len(path) - 1)]
            total_distance = sum(hop_distances)
            return [position_to_index[tuple(p)] for p in path], total_distance

        while open_set:
            _, current = heapq.heappop(open_set)
            visited_sats.add(position_to_index[tuple(current)])

            if np.array_equal(current, target):
                path_indices, distance = reconstruct_path(came_from, tuple(current))
                if distance > R_E:
                    print("Total distance is greater than Earth's radius: the path involves multiple hops.")
                return distance, list(visited_sats), path_indices

            for neighbor in get_neighbors(current, satellite_positions):
                if tuple(neighbor) in visited_sats:
                    continue
                tentative_g_cost = g_cost[tuple(current)] + edge_cost(current, neighbor)

                if tentative_g_cost < g_cost[tuple(neighbor)]:
                    g_cost[tuple(neighbor)] = tentative_g_cost
                    f_cost = tentative_g_cost + heuristic_cost_estimate(neighbor, target)
                    heapq.heappush(open_set, (f_cost, neighbor))
                    came_from[tuple(neighbor)] = tuple(current)

        return float('inf'), list(visited_sats), []  # No valid path

    def great_circle_distance(self, pos1, pos2, R_E=6371.8):
        #  great-circle  between  points
        lat1 = np.arcsin(pos1[2] / np.linalg.norm(pos1))
        lon1 = np.arctan2(pos1[1], pos1[0])
        lat2 = np.arcsin(pos2[2] / np.linalg.norm(pos2))
        lon2 = np.arctan2(pos2[1], pos2[0])

        dlat = lat2 - lat1
        dlon = lon2 - lon1
        a = np.sin(dlat / 2) ** 2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon / 2) ** 2
        c = 2 * np.arcsin(np.sqrt(a))
        return R_E * c

    def satellite_coverage_check(self,r1, r2, Re=6371, threshold=500):
        r1, r2 = np.array(r1), np.array(r2)
        d = np.linalg.norm(r1 - r2)
        #print(r1,"r1",r2,"r2","d",d)
        d_min = np.linalg.norm(np.cross(r1, r2)) / d
        return d_min > Re - threshold  # relxing constraint

    def satellite_coverage_check_all(self,satellites_eci,gs,path, Re=6371,threshold=500):
      for idxs in path:
        sat_eci = satellites_eci[idxs]
        r1, r2 = np.array(sat_eci), np.array(gs)
        d = np.linalg.norm(r1 - r2)
        d_min = np.linalg.norm(np.cross(r1, r2)) / d
        return d_min > Re - threshold  # relxing constraint




    def geodetic_to_eci(self, lat_deg, lon_deg, altitude_km=0, utc_time=None):
        if utc_time is None:
            utc_time = datetime.utcnow().replace(tzinfo=timezone.utc)

        lat = np.radians(lat_deg)
        lon = np.radians(lon_deg)
        R_E = 6371.8

        jd = self.julian_date(utc_time)
        gst = self.gst_from_julian(jd)
        lon_eci = lon + gst  # long  (ECI)

        x = (R_E + altitude_km) * np.cos(lat) * np.cos(lon_eci)
        y = (R_E + altitude_km) * np.cos(lat) * np.sin(lon_eci)
        z = (R_E + altitude_km) * np.sin(lat)

        return x, y, z

    def julian_date(self, utc_time):

        unix_epoch = datetime(1970, 1, 1, 0, 0, 0, tzinfo=timezone.utc)
        delta_seconds = (utc_time - unix_epoch).total_seconds()
        return 2440587.5 + delta_seconds / 86400.0

    def gst_from_julian(self, julian_date):
        T = (julian_date - 2451545.0) / 36525.0
        GST = 280.46061837 + 360.98564736629 * (julian_date - 2451545.0) + 0.000387933 * T ** 2 - (T ** 3 / 38710000.0)
        GST = GST % 360.0  # Kn 0 to 360
        return np.radians(GST)
    def geodetic_to_ecef(self, lat_deg, lon_deg, alt_km=0):
        lat = np.radians(lat_deg)
        lon = np.radians(lon_deg)
        x = (self.R_E + alt_km) * np.cos(lat) * np.cos(lon)
        y = (self.R_E + alt_km) * np.cos(lat) * np.sin(lon)
        z = (self.R_E + alt_km) * np.sin(lat)
        return np.array([x, y, z])

    def gmst(self, dt):
        jd = (dt - datetime(2000, 1, 1, 12)).total_seconds() / 86400.0 + 2451545.0
        T = (jd - 2451545.0) / 36525
        gmst_deg = 280.46061837 + 360.98564736629 * (jd - 2451545) + \
                   0.000387933 * T**2 - (T**3) / 38710000
        return np.radians(gmst_deg % 360)

    def eci_to_ecef(self, r_eci, dt):

        theta = self.gmst(dt)
        rot = np.array([
            [np.cos(theta), np.sin(theta), 0],
            [-np.sin(theta), np.cos(theta), 0],
            [0, 0, 1]
        ])
        return rot @ r_eci

    def has_line_of_sight_to_gs(self, satellites_eci: dict, gs_ecef,dt: datetime) -> dict:

        #gs_ecef = self.A_ecef
        result = {}

        for sat_id, sat_eci in satellites_eci.items():
            sat_ecef = self.eci_to_ecef(sat_eci, dt)
            vec = sat_ecef - gs_ecef
            vec_norm = np.linalg.norm(vec)
            gs_norm = np.linalg.norm(gs_ecef)

            cos_theta = np.dot(vec, gs_ecef) / (vec_norm * gs_norm)
            cos_theta = np.clip(cos_theta, -1.0, 1.0)
            theta_rad = np.arccos(cos_theta)
            elevation_deg = np.degrees(np.pi / 2 - theta_rad)

            result[sat_id] = elevation_deg > self.elevation_threshold

        return result
    def has_line_of_sight_to_both_gs(self, satellites_eci: dict, dt: datetime) -> dict:

      result = {}

      for sat_id, sat_eci in satellites_eci.items():
        sat_ecef = self.eci_to_ecef(sat_eci, dt)

        #  LOS to gs  A
        vec_a = sat_ecef - self.A_ecef
        cos_theta_a = np.dot(vec_a, self.A_ecef) / (np.linalg.norm(vec_a) * np.linalg.norm(self.A_ecef))
        elevation_deg_a = np.degrees(np.pi / 2 - np.arccos(np.clip(cos_theta_a, -1.0, 1.0)))

        #  LOS to  gs B
        vec_b = sat_ecef - self.B_ecef
        cos_theta_b = np.dot(vec_b, self.B_ecef) / (np.linalg.norm(vec_b) * np.linalg.norm(self.B_ecef))
        elevation_deg_b = np.degrees(np.pi / 2 - np.arccos(np.clip(cos_theta_b, -1.0, 1.0)))

        #  LOS to both gss
        result[sat_id] = (elevation_deg_a > self.elevation_threshold) and (elevation_deg_b > self.elevation_threshold)

      return result




epochs = 0
env = SatelliteRoutingEnv()
rewards = []
obs = env.reset()
print("Observation Shape:", obs.shape)

# ppo
model = PPO("MlpPolicy", env, learning_rate=0.00001, verbose=1,gamma=0.997)
model.learn(total_timesteps=8000)
model.save("ppo_satellite_routing")

# eval
done = False
while epochs < 800:
    action, _states = model.predict(obs)
    obs, reward, terminated, _ = env.step(action)
    rewards.append(reward)
    epochs += 1
    print(f"Action: {action}, Reward: {reward}")
mean_r = np.mean(rewards)

#
plt.figure(figsize=(10, 6)) ##

plt.plot(rewards, "g-o", label="Episode Reward", alpha=0.7)

plt.axhline(y=mean_r, color='r', linestyle='--', label=f'Mean Reward ({mean_r:.2f})')

plt.xlabel("Episode")
plt.ylabel("Reward")
plt.title("PPO Reward Over Time")
plt.legend() #
plt.grid(True) #
plt.show()

# #######################
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

def plot_constellation_with_route(satellites_eci, path_indices, start,end,R_E=6371):

    fig = plt.figure(figsize=(10, 8))
    ax = fig.add_subplot(111, projection='3d')

    #  earth
    u, v = np.mgrid[0:2*np.pi:100j, 0:np.pi:50j]
    x = R_E * np.cos(u) * np.sin(v)
    y = R_E * np.sin(u) * np.sin(v)
    z = R_E * np.cos(v)
    ax.plot_surface(x, y, z, color='blue', alpha=0.1)

    #  all sats
    for idx, pos in satellites_eci.items():
        if idx in path_indices:
            #  sats -- optimal route
            ax.scatter(pos[0], pos[1], pos[2], color='red', s=100, label='Optimal point' if idx == path_indices[0] else "")
        else:
            #  other sats
            ax.scatter(pos[0], pos[1], pos[2], color='gray', s=50, alpha=0.5)

    #  optimal route
    route_positions = [satellites_eci[idx] for idx in path_indices]
    route_x = [pos[0] for pos in route_positions]
    route_y = [pos[1] for pos in route_positions]
    route_z = [pos[2] for pos in route_positions]
    ax.plot(route_x, route_y, route_z, color='green', marker='o', markersize=8, label='Optimal Route')
    #------------------------berlin capetown
    ax.scatter(start[0],start[1],start[2], color='yellow',s=50 ,marker='*',  label='start')

    ax.scatter(end[0],end[1],end[2], color='black',s=50, marker='*', label='end ')

    # Add labels and legend
    ax.set_xlabel('X (km)')
    ax.set_ylabel('Y (km)')
    ax.set_zlabel('Z (km)')
    ax.set_title('Satellite Constellation with Optimal Route')
    plt.legend()
    plt.show()



def plot_satellite_constellation(satellite_positions):
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')

    x = [pos[0] for pos in satellite_positions.values()]
    y = [pos[1] for pos in satellite_positions.values()]
    z = [pos[2] for pos in satellite_positions.values()]

    ax.scatter(x, y, z, c='b', marker='o')

    ax.set_xlabel('X Position')
    ax.set_ylabel('Y Position')
    ax.set_zlabel('Z Position')
    ax.set_title('Satellite Constellation')

    plt.show()



def plot_routing_paths(satellite_positions, path_indices):
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')

    x = [pos[0] for pos in satellite_positions.values()]
    y = [pos[1] for pos in satellite_positions.values()]
    z = [pos[2] for pos in satellite_positions.values()]
    ax.scatter(x, y, z, c='b', marker='o')

    for i in range(len(path_indices) - 1):
        start = satellite_positions[path_indices[i]]
        end = satellite_positions[path_indices[i + 1]]
        ax.plot([start[0], end[0]], [start[1], end[1]], [start[2], end[2]], c='r')

    ax.set_xlabel('X Position')
    ax.set_ylabel('Y Position')
    ax.set_zlabel('Z Position')
    ax.set_title('Satellite Routing Paths')

    plt.show()
# Out:
# /home/student/anaconda3/envs/space/lib/python3.8/site-packages/gym/spaces/box.py:127: UserWarning: WARN: Box bound precision lowered by casting to float32
#   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# /home/student/anaconda3/envs/space/lib/python3.8/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# /home/student/anaconda3/envs/space/lib/python3.8/site-packages/stable_baselines3/common/on_policy_algorithm.py:150: UserWarning: You are trying to run PPO on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(
# /tmp/ipykernel_7218/420977193.py:464: RuntimeWarning: invalid value encountered in scalar divide
#   d_min = np.linalg.norm(np.cross(r1, r2)) / d
# Observation Shape: (4,)
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3758.1818564198497
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3815.086997611267
# reward in step -1000000.0
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1777.8264075420493
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1533.0328494296532
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2791.9922167389955
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3810.254653859317
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2778.646753742362
# reward in step -1000000.0
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2719.4375165507277
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2613.492115208139
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3830.4029878139504
# reward in step -1000000.0
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3793.4830138333537
# reward in step -1000000.0
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2854.6153056943194
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2858.7856300615476
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1740.1991122845704
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2384.927325889519
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2700.6049693123177
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2329.267914526005
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2574.1019666821894
# reward in step -1000000.0
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1777.826407542049
# reward in step -1000000.0
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1375.0569800127957
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1219.6377392315956
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2469.7574722234644
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1180.4907519543574
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3756.3200696903473
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3934.5508019980607
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2215.29058528869
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1185.4605108720611
# reward in step -1000000.0
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3933.8588291656974
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3700.8537731850056
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2296.7101333761975
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2881.4805562206857
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2845.927624254015
# reward in step -1000000.0
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1535.895345014887
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -4052.350245324235
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -4748.790555941296
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3561.041837667396
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -4882.606328644283
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1743.92748966519
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3428.347427982448
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2860.9208108107196
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -5117.454852531779
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1535.895345014887
# reward in step -1000000.0
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -4329.127282400957
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -4936.866399329964
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1535.895345014887
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1364.311530365081
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3797.755300511323
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2846.9007137933077
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2815.772921763728
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1777.8264075420493
# reward in step -1000000.0
# reward in step -1000000.0
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1424.3956958369579
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1764.855089065456
# reward in step -1000000.0
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3789.833689700114
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2646.98210898995
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2609.175786139962
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2336.570663211145
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2940.772626666014
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3077.2215180439725
# reward in step -1000000.0
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3854.487157072004
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3595.570502257443
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1535.895345014887
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3153.3151064379977
# reward in step -1000000.0
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3484.276105379715
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2864.1428067368824
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2953.7742268475345
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2423.0329914462213
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3165.3037420441256
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2907.679818920254
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1739.9474918493174
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1535.895345014887
# reward in step -1000000.0
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3806.048987759129
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3324.7771257184513
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1535.895345014887
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3086.1320522933142
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2657.444987505408
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1794.846386073169
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1355.6182528015315
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1535.895345014887
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2736.50385975699
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2580.1682541769073
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2143.1301811951344
# reward in step -1000000.0
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2808.7322670034287
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1378.7244392596178
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2430.8159816152347
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1777.0375607522003
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2942.6437998426545
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2799.776676740433
# reward in step -1000000.0
# reward in step -1000000.0
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1535.895345014887
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2975.343510108517
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2411.6559581760334
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3746.1622568722573
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1436.9142787359006
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1442.483842722756
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1739.5420271978533
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2506.5513839388495
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3701.024716475608
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2846.683611839235
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3698.9858949481018
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1739.2525260064172
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2267.957476608676
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1738.8758723707454
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3012.23227096124
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3909.8491157217827
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2183.597261817049
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1137.7138439791706
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2370.7724430084077
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3686.9861739464163
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2389.077382881887
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3694.570320022437
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1200.1118787650782
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1334.013127857755
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1202.9786774250003
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1739.9474918493174
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2398.7977674137733
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2972.7669317847754
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2420.503990260775
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1739.9474918493174
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1086.3282571573513
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2899.8305059078602
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3918.836937654374
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2162.205278396764
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2846.3185983933936
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1739.9474918493174
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2259.9617968726266
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1739.9474918493174
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3701.167890532644
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1089.0700713170927
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1743.0636586120704
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1047.0119982344759
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2330.0488201870517
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3829.2250162292826
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2448.415993536417
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1739.1605431485816
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3730.7276056625005
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3940.4934737889466
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1057.5378211998568
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2933.8657597985666
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2587.0376032033114
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2483.8357192786925
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3081.4115044360215
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1119.5501723387
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -4588.656780775892
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3058.5197062644424
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3835.5941244777937
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2227.559823537802
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3925.1562825413334
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2362.277745579602
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2364.5587724098714
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2611.154508921485
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3753.971606578143
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2436.015482376573
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1269.8831875202616
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -5206.112430799249
# reward in step -1000000.0
# reward in step -1000000.0
# reward in step -1000000.0
# reward in step -1000000.0
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -5221.97279636908
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1535.895345014887
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2630.3305587242266
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1535.895345014887
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2535.467460364077
# reward in step -1000000.0
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3834.36728847541
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -5241.053288174919
# reward in step -1000000.0
# reward in step -1000000.0
# reward in step -1000000.0
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2374.738025116873
# reward in step -1000000.0
# reward in step -1000000.0
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -4398.596067561651
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2203.3153330747587
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -5313.026479818889
# reward in step -1000000.0
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -5193.030810601718
# reward in step -1000000.0
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2248.1121594314636
# reward in step -1000000.0
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1535.895345014887
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -5222.968730902454
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -4204.745576402235
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3052.3323970093784
# reward in step -1000000.0
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1535.895345014887
# reward in step -1000000.0
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2203.3789747262094
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2122.4685138606487
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2091.862996551843
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1739.609845897043
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2082.892092120801
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3911.8484633305816
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3743.0152665632795
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1789.1988073670939
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1035.5720823020747
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2047.3042293087226
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1825.4570497297711
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2051.458294507811
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3151.157738763364
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2094.039366002814
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3686.9266016639144
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3854.707194690486
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1736.8241288819659
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -4028.336394409328
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3072.529389011287
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -5346.962897267611
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1535.895345014887
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2308.8342128504855
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2113.879928917107
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2305.4741506627834
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -4085.6357276727404
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1070.4445929775395
# reward in step -1000000.0
# reward in step -1000000.0
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1535.895345014887
# reward in step -1000000.0
# reward in step -1000000.0
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -5410.2689716171
# reward in step -1000000.0
# reward in step -1000000.0
# reward in step -1000000.0
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2309.7000220867576
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -5296.522723047237
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2838.8385853669192
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3881.3298167272274
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3049.752529255
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -4228.827945984495
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2286.277278817762
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2289.948216678068
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -5299.615615765631
# reward in step -1000000.0
# reward in step -1000000.0
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -5228.674077302291
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -5271.002067709001
# reward in step -1000000.0
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2307.7273919042636
# reward in step -1000000.0
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2285.518495598792
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -4194.748520277032
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3042.906869418077
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -4150.459490200269
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2334.7555924939193
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2301.0999953692763
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1535.895345014887
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3092.859397826
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -4281.234162424642
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2901.855885639621
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -4250.2343008653315
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -5271.226330331457
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2204.3781668354904
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1535.895345014887
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2218.018429096159
# reward in step -1000000.0
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2192.6515906604754
# reward in step -1000000.0
# reward in step -1000000.0
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -5284.387149729793
# reward in step -1000000.0
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -4064.23405454709
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2190.1780766473917
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2201.263329902402
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2190.075908086078
# reward in step -1000000.0
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2253.7951410080127
# reward in step -1000000.0
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -5250.178627325175
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -4182.730810167068
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2112.926388363752
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2096.2415423676475
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2850.9115930307516
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2134.0697885528925
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3914.187767508117
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2974.936709000967
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2078.6356997808452
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3692.714609115689
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3090.787458563056
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2851.2320556390496
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3760.770399088352
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2177.379071803217
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1739.9474918493174
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2852.407512307517
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2852.4782116164206
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2853.7648303350625
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2850.1542441567103
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1736.7232878934203
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2134.96842578817
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2220.876358031831
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1736.7492936954566
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2285.5904911601265
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3691.874424922327
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2192.93326070149
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2156.901394882816
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1818.6155294235946
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2109.1037014141193
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1080.820081064102
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2917.821482702143
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2241.0467506329323
# reward in step -1000000.0
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2287.6396519877862
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3921.337201549387
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2923.8654971943806
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1135.168048529483
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2956.8318759878007
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1158.0405366239738
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2305.82924532757
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2170.5034565398973
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2199.5347289609936
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2101.8836108982928
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2919.761444047318
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3742.930730295831
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3687.7100855359586
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2140.824760472901
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1791.1408937142737
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2847.6921079623407
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2344.391365467382
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3915.9913010130263
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2360.2639051092333
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1742.8469812996507
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3686.9236038474905
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2851.2510624440692
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1791.762597214187
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1130.4936512151075
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3745.054808424806
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2241.302137840781
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2204.684847228435
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1167.458451933476
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3915.276034810282
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2696.511260500367
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1742.4288791154195
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2368.391052748814
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1135.3989283765038
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1739.9474918493174
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2365.136142088658
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2955.9433726637208
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2902.686124267254
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2247.8538034299854
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2324.319290069296
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3686.8954219822267
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2321.415251168578
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3961.4615137838
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2854.8815581473236
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1739.9474918493174
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2157.0318506112217
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1157.081869681281
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2325.042573171833
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3739.1201929694
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1790.9704321417673
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1185.934638233896
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1095.5665374767539
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3698.8663715380762
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3911.759368399553
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1147.2221217379606
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2179.474337016687
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2162.137493032898
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2184.0439378279557
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3910.804950621315
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2212.9353519445385
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2425.3796666537805
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1787.6667363048778
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3918.5721944196016
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2213.3139078786044
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2844.6805173544017
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3690.143924870163
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3938.1967135063774
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2570.5634462782236
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1740.5045815324681
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2204.128119046838
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2848.718683522295
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1786.7901606055027
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1746.7506304360843
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2843.4727363674
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1248.3962757382158
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2245.854025223729
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3743.4103678219826
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3916.2412455903755
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3910.7932363084965
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2846.735793923035
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3739.635052815129
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3737.5124743523006
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2386.42571090526
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3959.036422577382
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1789.5731189336252
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1736.6973397565648
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3739.396748666875
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2893.3604431864396
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2426.6365935002646
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2412.571953842561
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2220.6210871297208
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2896.7854974197094
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1160.939864035041
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2196.217052801082
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2846.7990993143017
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1739.9474918493174
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2847.1916414830166
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2844.7694690874364
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2847.2905646206023
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3913.823869349334
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1736.6973397565648
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2895.5703543023615
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2355.375622580493
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2170.3878311150784
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2413.0524209934392
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2423.517060231382
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1169.883237513491
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1187.0605993690908
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1153.490637598338
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1738.482963843805
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1212.2712162775508
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3687.037096321403
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1199.4007080913102
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2391.8147206665462
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1736.6973397565648
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2431.799195378954
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3686.366269100684
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1176.287648227215
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3911.645720387456
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1239.2494740136
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1786.8758381733405
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2444.927692475421
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1182.7696611923102
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1739.3156709600248
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2843.580961866619
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1216.3808037825881
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3687.567776724863
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1739.643274574808
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2303.8342013923125
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1741.0948005166008
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2491.672255938788
# ...
# reward in step -2855.0372655723536
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2858.884730985671
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1535.895345014887
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3784.833101622781
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2555.27797190061
# reward in step -1000000.0
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3715.92943033621
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1535.895345014887
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2814.69346638309
# reward in step -1000000.0
# reward in step -1000000.0
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3041.2972868442994
# reward in step -1000000.0
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3032.11178160293
# reward in step -1000000.0
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -7081.023320156274
# reward in step -1000000.0
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3065.801452156435
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3026.2243830661178
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1535.895345014887
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3048.782670371106
# reward in step -1000000.0
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3048.4746949603955
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2952.011205690691
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2668.1209598826676
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2872.9124172588886
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3740.321113499183
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1535.895345014887
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1535.895345014887
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2563.5329818094033
# reward in step -1000000.0
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2723.2190342145577
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3064.937985675138
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3747.517796535057
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2965.1244310892002
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3764.889632915477
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1535.895345014887
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1739.9474918493174
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3757.5572274807982
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3758.009038551272
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1737.370290665172
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3764.3426940538225
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2912.6199499492877
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1736.6941581645049
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3031.3438770184366
# reward in step -1000000.0
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3843.5808815884798
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3037.702864325124
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3084.495260635279
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3798.237284855122
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3818.2720027266814
# reward in step -1000000.0
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2935.998638289452
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3109.950521851638
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3130.1839524340658
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2971.6290932463626
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1736.8654888584074
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1535.895345014887
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3902.490617910107
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1535.895345014887
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1535.895345014887
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1736.7248327462971
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1737.3600026160027
# reward in step -1000000.0
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3804.7590274947393
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2746.5833150565977
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2685.340962975036
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3774.532525900564
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2900.0594442794945
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3791.7006576078443
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2672.2412526204685
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2647.7680220398697
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2889.467199362379
# reward in step -1000000.0
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3723.4866112620994
# reward in step -1000000.0
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2768.653154007344
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2810.9510423672245
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3715.893735037582
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1736.6882278646424
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2489.5911987658255
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2451.3466421122152
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2893.3388059020754
# reward in step -1000000.0
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3758.247332455864
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1786.7186784768246
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3701.8228409635008
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2844.3223157035372
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2703.099775934038
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -3704.3317680893088
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2692.196239657399
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2893.895606813914
# reward in step -1000000.0
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2893.720961519497
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1736.9787163447434
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -1535.895345014887
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2786.8145967462633
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2792.3873038605184
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2847.787564224377
# Total distance is greater than Earth's radius: the path involves multiple hops.
# reward in step -2845.7513741722687
# reward in step -1000000.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 584
#     582 # ppo
#     583 model = PPO("MlpPolicy", env, learning_rate=0.00001, verbose=1,gamma=0.997)
# --> 584 model.learn(total_timesteps=8000)
#     585 model.save("ppo_satellite_routing")
#     587 # eval
#
# File ~/anaconda3/envs/space/lib/python3.8/site-packages/stable_baselines3/ppo/ppo.py:311, in PPO.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     302 def learn(
#     303     self: SelfPPO,
#     304     total_timesteps: int,
#    (...)
#     309     progress_bar: bool = False,
#     310 ) -> SelfPPO:
# --> 311     return super().learn(
#     312         total_timesteps=total_timesteps,
#     313         callback=callback,
#     314         log_interval=log_interval,
#     315         tb_log_name=tb_log_name,
#     316         reset_num_timesteps=reset_num_timesteps,
#     317         progress_bar=progress_bar,
#     318     )
#
# File ~/anaconda3/envs/space/lib/python3.8/site-packages/stable_baselines3/common/on_policy_algorithm.py:323, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     320 assert self.env is not None
#     322 while self.num_timesteps < total_timesteps:
# --> 323     continue_training = self.collect_rollouts(self.env, callback, self.rollout_buffer, n_rollout_steps=self.n_steps)
#     325     if not continue_training:
#     326         break
#
# File ~/anaconda3/envs/space/lib/python3.8/site-packages/stable_baselines3/common/on_policy_algorithm.py:218, in OnPolicyAlgorithm.collect_rollouts(self, env, callback, rollout_buffer, n_rollout_steps)
#     213     else:
#     214         # Otherwise, clip the actions to avoid out of bound error
#     215         # as we are sampling from an unbounded Gaussian distribution
#     216         clipped_actions = np.clip(actions, self.action_space.low, self.action_space.high)
# --> 218 new_obs, rewards, dones, infos = env.step(clipped_actions)
#     220 self.num_timesteps += env.num_envs
#     222 # Give access to local variables
#
# File ~/anaconda3/envs/space/lib/python3.8/site-packages/stable_baselines3/common/vec_env/base_vec_env.py:206, in VecEnv.step(self, actions)
#     199 """
#     200 Step the environments with the given action
#     201
#     202 :param actions: the action
#     203 :return: observation, reward, done, information
#     204 """
#     205 self.step_async(actions)
# --> 206 return self.step_wait()
#
# File ~/anaconda3/envs/space/lib/python3.8/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py:58, in DummyVecEnv.step_wait(self)
#      55 def step_wait(self) -> VecEnvStepReturn:
#      56     # Avoid circular imports
#      57     for env_idx in range(self.num_envs):
# ---> 58         obs, self.buf_rews[env_idx], terminated, truncated, self.buf_infos[env_idx] = self.envs[env_idx].step(
#      59             self.actions[env_idx]
#      60         )
#      61         # convert to SB3 VecEnv api
#      62         self.buf_dones[env_idx] = terminated or truncated
#
# File ~/anaconda3/envs/space/lib/python3.8/site-packages/stable_baselines3/common/monitor.py:94, in Monitor.step(self, action)
#      92 if self.needs_reset:
#      93     raise RuntimeError("Tried to step environment that needs reset")
# ---> 94 observation, reward, terminated, truncated, info = self.env.step(action)
#      95 self.rewards.append(float(reward))
#      96 if terminated or truncated:
#
# File ~/anaconda3/envs/space/lib/python3.8/site-packages/shimmy/openai_gym_compatibility.py:250, in GymV21CompatibilityV0.step(self, action)
#     241 def step(self, action: ActType) -> tuple[Any, float, bool, bool, dict]:
#     242     """Steps through the environment.
#     243
#     244     Args:
#    (...)
#     248         (observation, reward, terminated, truncated, info)
#     249     """
# --> 250     obs, reward, done, info = self.gym_env.step(action)
#     252     if self.render_mode is not None:
#     253         self.render()
#
# Cell In[21], line 322, in SatelliteRoutingEnv.step(self, action)
#     316 #random start and end----------------------------------
#     317 (self.A,self.B)=self.start_end_pairs[rand_point]
# --> 322 distance, visited_sats, path = self.a_star_routing(self.A, self.B, self.satellites_eci)
#     323 #print("distance in step",distance)
#     324
#     325 #gs changes every step either a or b
#     326 gs = self.B_ecef if np.random.rand() < 0.5 else self.A_ecef#
#
# Cell In[21], line 437, in SatelliteRoutingEnv.a_star_routing(self, source, target, satellite_positions, R_E)
#     435 if tuple(neighbor) in visited_sats:
#     436     continue
# --> 437 tentative_g_cost = g_cost[tuple(current)] + edge_cost(current, neighbor)
#     439 if tentative_g_cost < g_cost[tuple(neighbor)]:
#     440     g_cost[tuple(neighbor)] = tentative_g_cost
#
# Cell In[21], line 402, in SatelliteRoutingEnv.a_star_routing.<locals>.edge_cost(current, neighbor)
#     401 def edge_cost(current, neighbor):
# --> 402     return self.great_circle_distance(np.array(current), np.array(neighbor))
#
# Cell In[21], line 449, in SatelliteRoutingEnv.great_circle_distance(self, pos1, pos2, R_E)
#     447 def great_circle_distance(self, pos1, pos2, R_E=6371.8):
#     448     #  great-circle  between  points
# --> 449     lat1 = np.arcsin(pos1[2] / np.linalg.norm(pos1))
#     450     lon1 = np.arctan2(pos1[1], pos1[0])
#     451     lat2 = np.arcsin(pos2[2] / np.linalg.norm(pos2))
#
# File <__array_function__ internals>:200, in norm(*args, **kwargs)
#
# File ~/anaconda3/envs/space/lib/python3.8/site-packages/numpy/linalg/linalg.py:2495, in norm(x, ord, axis, keepdims)
#    2344 """
#    2345 Matrix or vector norm.
#    2346
#    (...)
#    2491
#    2492 """
#    2493 x = asarray(x)
# -> 2495 if not issubclass(x.dtype.type, (inexact, object_)):
#    2496     x = x.astype(float)
#    2498 # Immediately handle some default, simple, fast, and common cases.
#
# KeyboardInterrupt:

# %%
model = PPO.load("ppo_satellite_routing")

epochs = 0
rewards = []
obs = env.reset()
while epochs < 20:  # eval  10 episodes
    action, _states = model.predict(obs)
    obs, reward, terminated, info = env.step(action)
    rewards.append(reward)
    epochs += 1
    print(f"Episode: {epochs}, Reward: {reward}, Path Length: {info['path_length']}, Distance: {info['distance']}")


    if epochs == 1:
        #plot_satellite_constellation(env.satellites_eci)
        distance, visited_sats, path_indices = env.a_star_routing(env.A, env.B, env.satellites_eci)
        #plot_routing_paths(env.satellites_eci, path_indices)

        plot_constellation_with_route(env.satellites_eci, path_indices, env.A,env.B,R_E=6371)
    if epochs == 10:
        #plot_satellite_constellation(env.satellites_eci)
        distance, visited_sats, path_indices = env.a_star_routing(env.A, env.B, env.satellites_eci)
        #plot_routing_paths(env.satellites_eci, path_indices)

        plot_constellation_with_route(env.satellites_eci, path_indices, env.A,env.B,R_E=6371)
mean_r = np.mean(rewards)

plt.figure(figsize=(10, 6)) 

plt.plot(rewards, "g-o", label="Episode Reward", alpha=0.7) 

plt.axhline(y=mean_r, color='r', linestyle='--', label=f'Mean Reward ({mean_r:.2f})')

plt.xlabel("Episode")
plt.ylabel("Reward")
plt.title("PPO Reward Over Time")
plt.legend() 
plt.grid(True) 
plt.show()
